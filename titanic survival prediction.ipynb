# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\harsh\\OneDrive\\Desktop\\final year projects\\1.titanic survival prediction\\Titanic-Dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age']=df['Age'].fillna(df['Age'].median())

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Embarked']=df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df['Sex']=df['Sex'].map({'male':1,'female':0})

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df=pd.get_dummies(df,columns=['Embarked'],drop_first=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df.drop(['PassengerId','Name','Ticket','Fare'],axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch  Embarked_Q  Embarked_S
# 0           0       3    1  22.0      1      0           0           1
# 1           1       1    0  38.0      1      0           0           0
# 2           1       3    0  26.0      0      0           0           1
# 3           1       1    0  35.0      1      0           0           1
# 4           0       3    1  35.0      0      0           0           1
# ..        ...     ...  ...   ...    ...    ...         ...         ...
# 886         0       2    1  27.0      0      0           0           1
# 887         1       1    0  19.0      0      0           0           1
# 888         0       3    0  28.0      1      2           0           1
# 889         1       1    1  26.0      0      0           0           0
# 890         0       3    1  32.0      0      0           1           0
#
# [891 rows x 8 columns]

# %%
df.head(10)
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch  Embarked_Q  Embarked_S
# 0         0       3    1  22.0      1      0           0           1
# 1         1       1    0  38.0      1      0           0           0
# 2         1       3    0  26.0      0      0           0           1
# 3         1       1    0  35.0      1      0           0           1
# 4         0       3    1  35.0      0      0           0           1
# 5         0       3    1  28.0      0      0           1           0
# 6         0       1    1  54.0      0      0           0           1
# 7         0       3    1   2.0      3      1           0           1
# 8         1       3    0  27.0      0      2           0           1
# 9         1       2    0  14.0      1      0           0           0

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as se

# %%
se.barplot(x='Sex',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
se.barplot(x='Pclass',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
plt.figure(figsize=(10,10))
se.histplot(df[df['Survived']==1]['Age'],bins=20,color='blue',label='Survived',kde=False)
se.histplot(df[df['Survived']==0]['Age'],bins=20,color='green',label='Not Survived',kde=False)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop('Survived',axis=1)

# %%
y=df['Survived']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix ,classification_report

lr = LogisticRegression()
lr.fit(x_train, y_train)

# Make predictions and evaluate
y_pred_lr = lr.predict(x_test)
print('Logistic Regression Accuracy:', accuracy_score(y_test, y_pred_lr))
# Out:
# Logistic Regression Accuracy: 0.8044692737430168

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(max_depth=5,random_state=42)
dt.fit(x_train,y_train)
y_pred = dt.predict(x_test)

print('Decision Tree Accuracy:', accuracy_score(y_test,y_pred))
print('confusion matrix(logistic regression):\n',confusion_matrix(y_test,y_pred_lr))
print('confusion matrix(decision tree):\n',confusion_matrix(y_test,y_pred))
print('classification report(logistic regression):\n',classification_report(y_test,y_pred_lr))
print('classification report(decision tree):\n',classification_report(y_test,y_pred))
# Out:
# Decision Tree Accuracy: 0.7932960893854749
# confusion matrix(logistic regression):
#  [[90 15]
#  [20 54]]
# confusion matrix(decision tree):
#  [[95 10]
#  [27 47]]
# classification report(logistic regression):
#                precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84       105
#            1       0.78      0.73      0.76        74
#
#     accuracy                           0.80       179
#    macro avg       0.80      0.79      0.80       179
# weighted avg       0.80      0.80      0.80       179
#
# classification report(decision tree):
#                precision    recall  f1-score   support
#
#            0       0.78      0.90      0.84       105
#            1       0.82      0.64      0.72        74
#
#     accuracy                           0.79       179
#    macro avg       0.80      0.77      0.78       179
# weighted avg       0.80      0.79      0.79       179

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'max_depth': [3, 5, 7, 10], 'min_samples_split': [2, 5, 10]}
grid_search = GridSearchCV(DecisionTreeClassifier(), param_grid, cv=5)
grid_search.fit(x_train, y_train)
print("Best parameters:", grid_search.best_params_)
# Out:
# Best parameters: {'max_depth': 3, 'min_samples_split': 2}

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred_lr)

se.heatmap(cm, annot=True, fmt="d", cmap="Greens")
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
